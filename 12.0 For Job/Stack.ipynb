# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\ChengChen Xu\Desktop\GMV & 客单价.xlsx")

# %%
df
# Out:
#            店铺名     明细       7月       8月       9月      10月      11月      12月
# 0   moccona旗舰店  Gmv预估  1320000  1800000  1800000  1350000  5100000  2040000
# 1      阿尔卑斯旗舰店  Gmv预估   720000   810000  1620000  2430000  2970000  3600000
# 2        爱夸旗舰店  Gmv预估   200000   200000   200000   100000   300000    60000
# 3       荷美尔旗舰店  Gmv预估   510000   630000   720000   540000  1275000   720000
# 4      麦斯威尔旗舰店  Gmv预估  1300000  1300000  1500000   950000  5000000  2000000
# 5      那街那巷旗舰店  Gmv预估  1100000  1100000  1300000   800000  2300000  1500000
# 6       三得利旗舰店  Gmv预估  3168000  3550800  2288000   968000  5478000  1408000
# 7        世棒旗舰店  Gmv预估   350000   350000   550000   300000  1150000   750000
# 8       四季宝旗舰店  Gmv预估   120000   150000   150000    80000   300000   200000
# 9       味好美旗舰店  Gmv预估  1196000  1196000  1395000   930000  1820000  1395000
# 10       优诺旗舰店  Gmv预估   600000   600000   850000   800000  1600000  1200000
# ...

# %%
df.set_index(["店铺名","明细"],inplace=True)

# %%
df.stack().reset_index().to_excel(r"C:\Users\ChengChen Xu\Desktop\GMV & 客单价_stack.xlsx")
